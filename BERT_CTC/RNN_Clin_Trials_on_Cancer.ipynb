# %% [markdown]
# # Setup

# %%
# %%capture
! pip install datasets metrics transformers wandb

# %%
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from transformers import BertTokenizerFast, BertForSequenceClassification
from sklearn.model_selection import train_test_split
from transformers import Trainer, TrainingArguments
from transformers import BertModel, BertTokenizer
from transformers.file_utils import ModelOutput
from datasets import Dataset
from torch import nn
import pandas as pd
import torch
import gc

# %%
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # Custom BERT model

# %%
class BERTRNN(nn.Module):

    def __init__(self,
                 model_name='bert-base-uncased',
                 device='cuda',
                 num_classes=3):
        super(BERTRNN, self).__init__()
        self.bert = BertModel.from_pretrained(model_name)
        # RNN
        self.lstm = nn.LSTM(768, 256, batch_first=True, bidirectional=True).to(device)
        # FC
        self.fc = nn.Linear(256*2, num_classes).to(device)
        self.softmax = nn.LogSoftmax(dim=1).to(device)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.bert(input_ids,
                            attention_mask=attention_mask,
                            output_hidden_states=True)
        lstm_output, (h, c) = self.lstm(outputs[0])
        hidden = torch.cat((lstm_output[:, -1, :256],lstm_output[:, 0, 256:]), dim=-1)
        x = self.fc(hidden.view(-1,256*2))
        c = self.softmax(x)

        # Clean cache
        gc.collect()
        torch.cuda.empty_cache()
        del outputs

        # Compute loss
        loss = None
        if labels is not None:
            ce_loss = nn.CrossEntropyLoss()
            loss = ce_loss(c, labels)

        return ModelOutput({
            'loss': loss,
            'last_hidden_state': c
        })

model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name, do_lower_case=True)
model = BERTRNN(model_name)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # Pre-procesing

# %%
def process_data_to_model_inputs(batch):
    # tokenize the inputs and labels

    inputs = tokenizer(
        batch["1"],
        max_length=50,
        padding="max_length",
        truncation=True,
    )

    batch["input_ids"] = inputs.input_ids
    batch["attention_mask"] = inputs.attention_mask
    labels = list(map(lambda x: int(x.split('__label__')[1]), batch['0']))
    batch["label"] = labels

    return batch

def compute_metrics(pred):
  labels = pred.label_ids
  preds = pred.predictions.argmax(-1)
  # calculate f1 using sklearn's function
  f_score = f1_score(labels, preds, pos_label=0, average='binary')
  accuracy = accuracy_score(labels, preds)
  precision = precision_score(labels, preds, pos_label=0, average='binary')
  recall = recall_score(labels, preds, pos_label=0, average='binary')
  return {
      'f1_score': f_score,
      'accuracy': accuracy,
      'precision': precision,
      'recall': recall
  }
    
tokenize_batch_size = 8192
df = pd.read_csv('/content/drive/MyDrive/PoliTo/Deep Natural Language Procesing/Project/labeledEligibilitySample1000000.csv', sep='\t', header=None)

# %%
train_ds = Dataset.from_pandas(df)

train_ds = train_ds.map(
    process_data_to_model_inputs,
    batched=True,
    batch_size=32768,
    remove_columns=["0", "1"]
)

train_ds.set_format(
    type="torch",
    columns=["input_ids", "attention_mask", "label"]
)
# Out:
#   0%|          | 0/31 [00:00<?, ?ba/s]

# %%
train_testvalid = train_ds.train_test_split(train_size=0.9)
test_valid = train_testvalid['test'].train_test_split(test_size=0.5)

# %% [markdown]
# # Training and evaluation

# %%
training_args = TrainingArguments(
    output_dir='./RNN_CTC_results',          # output directory
    num_train_epochs=2,              # total number of training epochs
    per_device_train_batch_size=128,  # batch size per device during training
    per_device_eval_batch_size=128,   # batch size for evaluation
    fp16=True,                       # enable fp16 apex training
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs',            # directory for storing logs
    load_best_model_at_end=True,     # load the best model when finished training (default metric is loss)
    # but you can specify `metric_for_best_model` argument to change to accuracy or other metric
    logging_steps=400,               # log & save weights each logging_steps
    save_steps=400,
    evaluation_strategy="steps",     # evaluate each `logging_steps`
    report_to="wandb"
)

trainer = Trainer(
    model=model,                         # the instantiated Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_testvalid['train'],         # training dataset
    eval_dataset=test_valid['train'],          # evaluation dataset
    compute_metrics=compute_metrics,     # the callback that computes metrics of interest
)

trainer.train()

preds = trainer.predict(test_valid['test'])

preds[2]
# Out:
# Using amp half precision backend
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 900000
#   Num Epochs = 2
#   Instantaneous batch size per device = 128
#   Total train batch size (w. parallel, distributed & accumulation) = 128
#   Gradient Accumulation steps = 1
#   Total optimization steps = 14064
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
#                     Syncing run <strong><a href="https://wandb.ai
td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.127600</td>
#       <td>0.144820</td>
#       <td>0.948014</td>
#       <td>0.947980</td>
#       <td>0.947125</td>
#       <td>0.948906</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.127600</td>
#       <td>0.139651</td>
#       <td>0.949561</td>
#       <td>0.949780</td>
#       <td>0.953449</td>
#       <td>0.945705</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>0.126800</td>
#       <td>0.136340</td>
#       <td>0.950096</td>
#       <td>0.950420</td>
#       <td>0.956081</td>
#       <td>0.944184</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.125800</td>
#       <td>0.137043</td>
#       <td>0.950075</td>
#       <td>0.950260</td>
#       <td>0.953348</td>
#       <td>0.946825</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.122300</td>
#       <td>0.132698</td>
#       <td>0.950428</td>
#       <td>0.950780</td>
#       <td>0.957001</td>
#       <td>0.943944</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>0.122000</td>
#       <td>0.133650</td>
#       <td>0.951308</td>
#       <td>0.951520</td>
#       <td>0.955222</td>
#       <td>0.947425</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>0.122400</td>
#       <td>0.131235</td>
#       <td>0.951626</td>
#       <td>0.952020</td>
#       <td>0.959228</td>
#       <td>0.944144</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>0.117100</td>
#       <td>0.129635</td>
#       <td>0.953092</td>
#       <td>0.953260</td>
#       <td>0.956259</td>
#       <td>0.949946</td>
#     </tr>
#     <tr>
#       <td>11600</td>
#       <td>0.120400</td>
#       <td>0.129813</td>
#       <td>0.952629</td>
#       <td>0.953000</td>
#       <td>0.959943</td>
#       <td>0.945425</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.113000</td>
#       <td>0.131734</td>
#       <td>0.950639</td>
#       <td>0.951520</td>
#       <td>0.967945</td>
#       <td>0.933942</td>
#     </tr>
#     <tr>
#       <td>12400</td>
#       <td>0.113600</td>
#       <td>0.127638</td>
#       <td>0.953375</td>
#       <td>0.953880</td>
#       <td>0.963662</td>
#       <td>0.943304</td>
#     </tr>
#     <tr>
#       <td>12800</td>
#       <td>0.118100</td>
#       <td>0.123979</td>
#       <td>0.953838</td>
#       <td>0.954260</td>
#       <td>0.962444</td>
#       <td>0.945385</td>
#     </tr>
#     <tr>
#       <td>13200</td>
#       <td>0.109700</td>
#       <td>0.126192</td>
#       <td>0.953861</td>
#       <td>0.954460</td>
#       <td>0.966294</td>
#       <td>0.941744</td>
#     </tr>
#     <tr>
#       <td>13600</td>
#       <td>0.111400</td>
#       <td>0.123590</td>
#       <td>0.954586</td>
#       <td>0.954960</td>
#       <td>0.962309</td>
#       <td>0.946985</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.112600</td>
#       <td>0.123779</td>
#       <td>0.954460</td>
#       <td>0.954940</td>
#       <td>0.964461</td>
#       <td>0.944665</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-400
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-800
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-1200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-1600
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-2000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-2400
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-2800
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-3200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-3600
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-4000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-4400
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-4800
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-5200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-5600
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-6000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-6400
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-6800
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-7200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-7600
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-8000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-8400
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-8800
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-9200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-9600
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-10000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-10400
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-10800
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-11200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-11600
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-12000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-12400
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-12800
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-13200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-13600
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 50000
#   Batch size = 128
# Saving model checkpoint to ./RNN_CTC_results/checkpoint-14000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./RNN_CTC_results/checkpoint-13600 (score: 0.12358961999416351).
# ***** Running Prediction *****
#   Num examples = 50000
#   Batch size = 128
#     <div>
#
#       <progress value='391' max='391' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [391/391 01:40]
#     </div>
# {'test_accuracy': 0.95444,
#  'test_f1_score': 0.9540466392318244,
#  'test_loss': 0.12768808007240295,
#  'test_precision': 0.9620031731825394,
#  'test_recall': 0.9462206394301949,
#  'test_runtime': 100.8319,
#  'test_samples_per_second': 495.875,
#  'test_steps_per_second': 3.878}

# %%
import torch
torch.save(trainer.model, '/content/RNN_model.model')
